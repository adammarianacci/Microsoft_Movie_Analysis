# %% [markdown]
# # Introduction
#
# ## Final Project Submission
#
# ***
# - Student Name: Adam Marianacci
# - Student Pace: Flex
# - Scheduled project review date/time: 5/23/23 1:00pm EST
# - Instructor Name: Morgan Jones

# %% [markdown]
# # Business Understanding

# %% [markdown]
# This project analyzes what types of films Microsoft should create in their new movie studio using various movie data sets. Microsoft currently does not know anything about creating movies and they need help in deciding what films to create. Exploring movie data sets will tell what types of films are doing the best in the box office and this well help Microsoft decide on which creative direction they should go in to be successful.

# %% [markdown]
# # Data Understanding

# %% [markdown]
# Each dataset used in this project contains thousands of entries. The datasets are from
#  * [Box Office Mojo](https://www.boxofficemojo.com/)
#  * [IMDB](https://www.imdb.com/)
#  * [Rotten Tomatoes](https://www.rottentomatoes.com/)
#  * [The Movie DB](https://www.themoviedb.org/)
#  * [The Numbers](https://www.the-numbers.com/)
#
# They contain data such as movie titles/release date/domestic and worldwide gross/popularity and genre to name a few. The data used in this research is suitable for the project because it contains various information that shows what movies are doing or have done the best in the box office.

# %% [markdown]
# # Data Preperation

# %% [markdown]
# I started by importing the appropriate libraries to start my data preperation.

# %%
import pandas as pd
import numpy as np
import sqlite3
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.float_format', lambda x: '%.0f' % x)

# %%
# Loading the 'movie budgets' file.
movie_budgets_df = pd.read_csv('data/tn.movie_budgets.csv.gz', index_col=0)

# %%
# Gathering information about the Data Frame.
movie_budgets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5782 entries, 1 to 82
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       5782 non-null   object
#  1   movie              5782 non-null   object
#  2   production_budget  5782 non-null   object
#  3   domestic_gross     5782 non-null   object
#  4   worldwide_gross    5782 non-null   object
# dtypes: object(5)
# memory usage: 271.0+ KB

# %% [markdown]
# There are no missing values from the above dataframe.

# %%
# Previewing the first 5 rows
movie_budgets_df.head()
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget domestic_gross worldwide_gross
# id
# 1       $425,000,000   $760,507,625  $2,776,345,279
# 2       $410,600,000   $241,063,875  $1,045,663,875
# 3       $350,000,000    $42,762,350    $149,762,350
# 4       $330,600,000   $459,005,868  $1,403,013,963
# 5       $317,000,000   $620,181,382  $1,316,721,747

# %% [markdown]
# I needed to format to proper datetime format so that I could eventually filter movies by year and month if needed. Eventually will be looking to see if there are any connections between high grossing movies and when in the calendar year they were released.

# %%
# Converting the df to proper datetime format
movie_budgets_df['release_date'] = pd.to_datetime(movie_budgets_df['release_date'])

# %% [markdown]
# I was running into an issue converting strings to integers for dollar values. I searched the following in google: `converting dollars from str to integers pandas` and found this [solution](https://stackoverflow.com/a/32464612).

# %%
# Getting rid of the '$' and commas in 'gross' and 'budget' columns to convert the string to an integer.
movie_budgets_df['worldwide_gross'] = movie_budgets_df['worldwide_gross'].apply(
    lambda x: int(x.replace('$','').replace(',','')))
movie_budgets_df['production_budget'] = movie_budgets_df['production_budget'].apply(
    lambda x: int(x.replace('$','').replace(',','')))
movie_budgets_df['domestic_gross'] = movie_budgets_df['domestic_gross'].apply(
    lambda x: int(x.replace('$','').replace(',','')))

# %%
# Looking at the highest grossing movies worldwide
sorted_worldwide_gross_movie_budgets_df = movie_budgets_df.sort_values('worldwide_gross', ascending=False)

# %%
# Coverting release_date to proper dates
sorted_worldwide_gross_movie_budgets_df['release_date'] = pd.to_datetime(sorted_worldwide_gross_movie_budgets_df['release_date'])

# %%
sorted_worldwide_gross_movie_budgets_df
# Out:
#    release_date                                 movie  production_budget  \
# id
# 1    2009-12-18                                Avatar          425000000
# 43   1997-12-19                               Titanic          200000000
# 6    2015-12-18  Star Wars Ep. VII: The Force Awakens          306000000
# 7    2018-04-27                Avengers: Infinity War          300000000
# 34   2015-06-12                        Jurassic World          215000000
# ..          ...                                   ...                ...
# 75   2005-12-31                       Insomnia Manica             500000
# 74   2012-07-17                       Girls Gone Dead             500000
# 73   2012-04-03                         Enter Nowhere             500000
# 72   2010-12-31                                Drones             500000
# 69   2008-12-12                The Kings of Appletown            7000000
#
#     domestic_gross  worldwide_gross
# id
# 1        760507625       2776345279
# 43       659363944       2208208395
# 6        936662225       2053311220
# 7        678815482       2048134200
# 34       652270625       1648854864
# ..             ...              ...
# 75               0                0
# 74               0                0
# 73               0                0
# 72               0                0
# 69               0                0
#
# [5782 rows x 5 columns]

# %%
sorted_worldwide_gross_movie_budgets_df = sorted_worldwide_gross_movie_budgets_df.sort_values(by=['release_date', 'worldwide_gross'], ascending=False)

# %%
sorted_worldwide_gross_movie_budgets_df = sorted_worldwide_gross_movie_budgets_df.sort_values(by='release_date', ascending=False)

# %%
sorted_worldwide_gross_movie_budgets_df = sorted_worldwide_gross_movie_budgets_df.sort_values(by='worldwide_gross', ascending=False)

# %%
# Getting descriptive statistics on the sorted worldwide gross data set.
sorted_worldwide_gross_movie_budgets_df.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross
# count               5782            5782             5782
# mean            31587757        41873327         91487461
# std             41812077        68240597        174719969
# min                 1100               0                0
# 25%              5000000         1429534          4125415
# 50%             17000000        17225945         27984448
# 75%             40000000        52348662         97645836
# max            425000000       936662225       2776345279

# %% [markdown]
# The mean for the production budget is around 31,000,000, the median is 17,000,000 which shows that there are certain films pulling the mean higher when in reality the majority of films are around the 17,000,000 mark.This number is in USD. This skew is also happening in the Worldwide gross column. The mean for worldwide gross is around 914,000,000 with the median only at 279,000,000.

# %%
sorted_worldwide_gross_movie_budgets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5782 entries, 1 to 6
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       5782 non-null   datetime64[ns]
#  1   movie              5782 non-null   object
#  2   production_budget  5782 non-null   int64
#  3   domestic_gross     5782 non-null   int64
#  4   worldwide_gross    5782 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 271.0+ KB

# %%
# Loading the tmdb movies file.
tmdb_movies_df = pd.read_csv('data/tmdb.movies.csv.gz', index_col=0)

# %%
tmdb_movies_df.head()
# Out:
#              genre_ids     id original_language  \
# 0      [12, 14, 10751]  12444                en
# 1  [14, 12, 16, 10751]  10191                en
# 2        [12, 28, 878]  10138                en
# 3      [16, 35, 10751]    862                en
# 4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1          34   2010-11-19
# 1                      How to Train Your Dragon          29   2010-03-26
# 2                                    Iron Man 2          29   2010-05-07
# 3                                     Toy Story          28   1995-11-22
# 4                                     Inception          28   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1             8       10788
# 1                      How to Train Your Dragon             8        7610
# 2                                    Iron Man 2             7       12368
# 3                                     Toy Story             8       10174
# 4                                     Inception             8       22186

# %% [markdown]
# I imported the above dataframe because it had valuable information regarding release date and genre_ids which allowed me to draw comparisons between popularity,release date, and genres between films.

# %%
# Gathering information about the Data Frame.
tmdb_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26517 entries, 0 to 26516
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          26517 non-null  object
#  1   id                 26517 non-null  int64
#  2   original_language  26517 non-null  object
#  3   original_title     26517 non-null  object
#  4   popularity         26517 non-null  float64
#  5   release_date       26517 non-null  object
#  6   title              26517 non-null  object
#  7   vote_average       26517 non-null  float64
#  8   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 2.0+ MB

# %%
# Converting dates to actual dates.
tmdb_movies_df['release_date'] = pd.to_datetime(tmdb_movies_df['release_date'])

# %% [markdown]
# This will eventually allow me to sort films and look at release dates more clearly.

# %%
# Previewing the first 5 rows of the Data Frame.
tmdb_movies_df.head()
# Out:
#              genre_ids     id original_language  \
# 0      [12, 14, 10751]  12444                en
# 1  [14, 12, 16, 10751]  10191                en
# 2        [12, 28, 878]  10138                en
# 3      [16, 35, 10751]    862                en
# 4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1          34   2010-11-19
# 1                      How to Train Your Dragon          29   2010-03-26
# 2                                    Iron Man 2          29   2010-05-07
# 3                                     Toy Story          28   1995-11-22
# 4                                     Inception          28   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1             8       10788
# 1                      How to Train Your Dragon             8        7610
# 2                                    Iron Man 2             7       12368
# 3                                     Toy Story             8       10174
# 4                                     Inception             8       22186

# %% [markdown]
# I wanted to see which movies had the highest popularity rating and eventually wanted to look at which genres were associated with the films with the highest popularity ratings.

# %%
# Sorting movies by most popular.
sorted_popularity_tmdb_movies_df = tmdb_movies_df.sort_values('popularity', ascending=False)

# %%
import ast

# %% [markdown]
# I was running into an issue the list to an actual python numeric list. I searched the following in google: `converting lists to numeric in pandas` and found this [solution](https://stackoverflow.com/questions/55144642/python-pandas-convert-list-of-objects-to-a-list-of-integer). When converting to numeric value I can actually sort numerically which was not possible before.

# %%
# Convert the string representation of the list to an actual Python list
sorted_popularity_tmdb_movies_df['genre_ids'] = sorted_popularity_tmdb_movies_df['genre_ids'].apply(ast.literal_eval)

# Convert the list to a numeric type
sorted_popularity_tmdb_movies_df['genre_ids'] = sorted_popularity_tmdb_movies_df['genre_ids'].apply(pd.to_numeric)

# %%
type(sorted_popularity_tmdb_movies_df['genre_ids'][0])
# Out:
# numpy.ndarray

# %%
genre_conversion_df = sorted_popularity_tmdb_movies_df[['genre_ids','original_title','release_date']].copy()
genre_conversion_df.head()
# Out:
#                    genre_ids                             original_title  \
# 23811           [12, 28, 14]                     Avengers: Infinity War
# 11019               [28, 53]                                  John Wick
# 23812  [28, 12, 16, 878, 35]          Spider-Man: Into the Spider-Verse
# 11020           [28, 12, 14]  The Hobbit: The Battle of the Five Armies
# 5179           [878, 28, 12]                               The Avengers
#
#       release_date
# 23811   2018-04-27
# 11019   2014-10-24
# 23812   2018-12-14
# 11020   2014-12-17
# 5179    2012-05-04

# %%
genre_conversion_df
# Out:
#                    genre_ids                             original_title  \
# 23811           [12, 28, 14]                     Avengers: Infinity War
# 11019               [28, 53]                                  John Wick
# 23812  [28, 12, 16, 878, 35]          Spider-Man: Into the Spider-Verse
# 11020           [28, 12, 14]  The Hobbit: The Battle of the Five Armies
# 5179           [878, 28, 12]                               The Avengers
# ...                      ...                                        ...
# 13877                [10749]                              Crème Caramel
# 13878                  [878]                                      Elegy
# 13879                   [35]                                     Jaguar
# 13880                     []             Unleashed! A Dog Dancing Story
# 26516               [53, 27]                                 The Church
#
#       release_date
# 23811   2018-04-27
# 11019   2014-10-24
# 23812   2018-12-14
# 11020   2014-12-17
# 5179    2012-05-04
# ...            ...
# 13877   2014-05-20
# 13878   2014-09-10
# 13879   2014-09-21
# 13880   2014-02-13
# 26516   2018-10-05
#
# [26517 rows x 3 columns]

# %% [markdown]
# Creating a dataframe that displayed genre_ids to corresponding genre titles.

# %%
genre_conversion_df = genre_conversion_df.explode('genre_ids')

# %%
genre_ids = {
    'Action': 28,
    'Adventure': 12,
    'Animation': 16,
    'Comedy': 35,
    'Crime': 80,
    'Documentary': 99,
    'Drama': 18,
    'Family': 10751,
    'Fantasy': 14,
    'History': 36,
    'Horror': 27,
    'Music': 10402,
    'Mystery': 9648,
    'Romance': 10749,
    'ScienceFiction': 878,
    'TVMovie': 10770,
    'Thriller': 53,
    'War': 10752,
    'Western': 37
}

# %%
for key, value in genre_ids.items():
    print(key, value)
# Out:
# Action 28
# Adventure 12
# Animation 16
# Comedy 35
# Crime 80
# Documentary 99
# Drama 18
# Family 10751
# Fantasy 14
# History 36
# Horror 27
# Music 10402
# Mystery 9648
# Romance 10749
# ScienceFiction 878
# TVMovie 10770
# Thriller 53
# War 10752
# Western 37

# %%
for key, value in genre_ids.items():
    genre_conversion_df['genre_ids'] = genre_conversion_df['genre_ids'].replace(value, key)

# %%
genre_conversion_df
# Out:
#             genre_ids                  original_title release_date
# 23811       Adventure          Avengers: Infinity War   2018-04-27
# 23811          Action          Avengers: Infinity War   2018-04-27
# 23811         Fantasy          Avengers: Infinity War   2018-04-27
# 11019          Action                       John Wick   2014-10-24
# 11019        Thriller                       John Wick   2014-10-24
# ...               ...                             ...          ...
# 13878  ScienceFiction                           Elegy   2014-09-10
# 13879          Comedy                          Jaguar   2014-09-21
# 13880             NaN  Unleashed! A Dog Dancing Story   2014-02-13
# 26516        Thriller                      The Church   2018-10-05
# 26516          Horror                      The Church   2018-10-05
#
# [47834 rows x 3 columns]

# %%
# Looking at the top 30 most popular movies in the data set.
sorted_popularity_tmdb_movies_df.head(30)
# Out:
#                      genre_ids      id original_language  \
# 23811             [12, 28, 14]  299536                en
# 11019                 [28, 53]  245891                en
# 23812    [28, 12, 16, 878, 35]  324857                en
# 11020             [28, 12, 14]  122917                en
# 5179             [878, 28, 12]   24428                en
# 11021            [28, 878, 12]  118340                en
# 20617            [878, 28, 53]  335984                en
# 23813            [878, 28, 53]  335984                en
# 23814                     [12]  338952                en
# 23815  [10751, 16, 35, 14, 12]  404368                en
# 20618        [28, 12, 878, 18]  315635                en
# 20619             [53, 28, 80]  324552                en
# 20620            [28, 18, 878]  263115                en
# 23816        [28, 12, 878, 35]  363088                en
# 14169            [28, 12, 878]   99861                en
# 23817        [28, 12, 14, 878]  284054                en
# 23818                [878, 28]  335983                en
# 20621         [28, 12, 35, 14]  284053                en
# 23819         [28, 12, 35, 14]  284053                en
# 23820            [28, 12, 878]  424783                en
# 11022        [28, 12, 14, 878]  127585                en
# 20622        [28, 12, 35, 878]  283995                en
# 23821                 [12, 14]  428078                en
# 23822             [12, 28, 53]  375588                en
# 17381        [28, 12, 878, 14]  246655                en
# 17382            [12, 28, 878]  271110                en
# 23823             [28, 35, 12]  383498                en
# 23824             [28, 12, 14]  297802                en
# 2468              [12, 14, 28]   10195                en
# 23825              [18, 10402]  424694                en
#
#                                     original_title  popularity release_date  \
# 23811                       Avengers: Infinity War          81   2018-04-27
# 11019                                    John Wick          78   2014-10-24
# 23812            Spider-Man: Into the Spider-Verse          61   2018-12-14
# 11020    The Hobbit: The Battle of the Five Armies          54   2014-12-17
# 5179                                  The Avengers          50   2012-05-04
# 11021                      Guardians of the Galaxy          50   2014-08-01
# 20617                            Blade Runner 2049          49   2017-10-06
# 23813                            Blade Runner 2049          49   2017-10-06
# 23814  Fantastic Beasts: The Crimes of Grindelwald          49   2018-11-16
# 23815                    Ralph Breaks the Internet          48   2018-11-21
# 20618                       Spider-Man: Homecoming          47   2017-07-07
# 20619                         John Wick: Chapter 2          45   2017-02-10
# 20620                                        Logan          45   2017-03-03
# 23816                         Ant-Man and the Wasp          45   2018-07-06
# 14169                      Avengers: Age of Ultron          44   2015-05-01
# 23817                                Black Panther          44   2018-02-16
# 23818                                        Venom          44   2018-10-05
# 20621                               Thor: Ragnarok          43   2017-11-03
# 23819                               Thor: Ragnarok          43   2017-11-03
# 23820                                    Bumblebee          43   2018-12-21
# 11022                   X-Men: Days of Future Past          42   2014-05-23
# 20622               Guardians of the Galaxy Vol. 2          40   2017-05-05
# 23821                               Mortal Engines          40   2018-12-14
# 23822                                   Robin Hood          40   2018-11-21
# 17381                            X-Men: Apocalypse          39   2016-05-27
# 17382                   Captain America: Civil War          39   2016-05-06
# 23823                                   Deadpool 2          39   2018-05-10
# 23824                                      Aquaman          38   2018-12-21
# 2468                                          Thor          38   2011-05-06
# 23825                            Bohemian Rhapsody          37   2018-11-02
#
#                                              title  vote_average  vote_count
# 23811                       Avengers: Infinity War             8       13948
# 11019                                    John Wick             7       10081
# 23812            Spider-Man: Into the Spider-Verse             8        4048
# 11020    The Hobbit: The Battle of the Five Armies             7        8392
# 5179                                  The Avengers             8       19673
# 11021                      Guardians of the Galaxy             8       17958
# 20617                            Blade Runner 2049             7        6679
# 23813                            Blade Runner 2049             7        6679
# 23814  Fantastic Beasts: The Crimes of Grindelwald             7        4870
# 23815                    Ralph Breaks the Internet             7        2626
# 20618                       Spider-Man: Homecoming             7       11585
# 20619                         John Wick: Chapter 2             7        5863
# 20620                                        Logan             8       12330
# 23816                         Ant-Man and the Wasp             7        6290
# 14169                      Avengers: Age of Ultron             7       13457
# 23817                                Black Panther             7       12365
# 23818                                        Venom             7        6206
# 20621                               Thor: Ragnarok             8       11380
# 23819                               Thor: Ragnarok             8       11380
# 23820                                    Bumblebee             6        2425
# 11022                   X-Men: Days of Future Past             8       10062
# 20622               Guardians of the Galaxy Vol. 2             8       12535
# 23821                               Mortal Engines             6        1751
# 23822                                   Robin Hood             6        1194
# 17381                            X-Men: Apocalypse             6        8348
# 17382                   Captain America: Civil War             7       14000
# 23823                                   Deadpool 2             8        8773
# 23824                                      Aquaman             7        6155
# 2468                                          Thor             7       12764
# 23825                            Bohemian Rhapsody             8        7629

# %%
genre_popularity_df = sorted_popularity_tmdb_movies_df[['genre_ids', 'popularity']]

# %% [markdown]
# I had to look up the genre_ids on the Movie Database website https://www.themoviedb.org/talk/5daf6eb0ae36680011d7e6ee. To see which id's were associated with what genre.

# %%
# Loading the 'movie gross' file.
movie_gross_df = pd.read_csv('data/bom.movie_gross.csv.gz', index_col=0)

# %%
# Gatherting information about the Data Frame.
movie_gross_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3387 entries, Toy Story 3 to An Actor Prepares
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   studio          3382 non-null   object
#  1   domestic_gross  3359 non-null   float64
#  2   foreign_gross   2037 non-null   object
#  3   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 132.3+ KB

# %% [markdown]
# Noticing that there are a good amount of missing values from this dataframe.

# %%
# Checking for how many missing values there are in each column. 
movie_gross_df.isna().sum()
# Out:
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
# Because it is a small amount I decided to drop the missing values from the domestic_gross column
movie_gross_df.dropna(subset=['domestic_gross'], inplace=True)

# %%
# Checking to see if the missing values were dropped
movie_gross_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3359 entries, Toy Story 3 to An Actor Prepares
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   studio          3356 non-null   object
#  1   domestic_gross  3359 non-null   float64
#  2   foreign_gross   2009 non-null   object
#  3   year            3359 non-null   int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 131.2+ KB

# %%
# Previewing the first 5 rows in the Data Frame.
movie_gross_df.head()
# Out:
#                                             studio  domestic_gross  \
# title
# Toy Story 3                                     BV       415000000
# Alice in Wonderland (2010)                      BV       334200000
# Harry Potter and the Deathly Hallows Part 1     WB       296000000
# Inception                                       WB       292600000
# Shrek Forever After                           P/DW       238700000
#
#                                             foreign_gross  year
# title
# Toy Story 3                                     652000000  2010
# Alice in Wonderland (2010)                      691300000  2010
# Harry Potter and the Deathly Hallows Part 1     664300000  2010
# Inception                                       535700000  2010
# Shrek Forever After                             513900000  2010

# %%
# Sorting movies by the highest domestic gross
sorted_movie_gross_domestic_df = movie_gross_df.sort_values('domestic_gross', ascending=False)

# %%
# Viewing the top 30 results
sorted_movie_gross_domestic_df.head(30)
# Out:
#                                             studio  domestic_gross  \
# title
# Star Wars: The Force Awakens                    BV       936700000
# Black Panther                                   BV       700100000
# Avengers: Infinity War                          BV       678800000
# Jurassic World                                Uni.       652300000
# Marvel's The Avengers                           BV       623400000
# Star Wars: The Last Jedi                        BV       620200000
# Incredibles 2                                   BV       608600000
# Rogue One: A Star Wars Story                    BV       532200000
# Beauty and the Beast (2017)                     BV       504000000
# Finding Dory                                    BV       486300000
# Avengers: Age of Ultron                         BV       459000000
# The Dark Knight Rises                           WB       448100000
# The Hunger Games: Catching Fire                LGF       424700000
# Jurassic World: Fallen Kingdom                Uni.       417700000
# Toy Story 3                                     BV       415000000
# Wonder Woman                                    WB       412600000
# Iron Man 3                                      BV       409000000
# Captain America: Civil War                      BV       408100000
# The Hunger Games                               LGF       408000000
# Jumanji: Welcome to the Jungle                Sony       404500000
# Frozen                                          BV       400700000
# Guardians of the Galaxy Vol. 2                  BV       389800000
# Harry Potter and the Deathly Hallows Part 2     WB       381000000
# The Secret Life of Pets                       Uni.       368400000
# Despicable Me 2                               Uni.       368100000
# The Jungle Book (2016)                          BV       364000000
# Deadpool                                       Fox       363100000
# Inside Out                                      BV       356500000
# Furious 7                                     Uni.       353000000
# Transformers: Dark of the Moon                P/DW       352400000
#
#                                             foreign_gross  year
# title
# Star Wars: The Force Awakens                      1,131.6  2015
# Black Panther                                   646900000  2018
# Avengers: Infinity War                            1,369.5  2018
# Jurassic World                                    1,019.4  2015
# Marvel's The Avengers                           895500000  2012
# Star Wars: The Last Jedi                        712400000  2017
# Incredibles 2                                   634200000  2018
# Rogue One: A Star Wars Story                    523900000  2016
# Beauty and the Beast (2017)                     759500000  2017
# Finding Dory                                    542300000  2016
# Avengers: Age of Ultron                         946400000  2015
# The Dark Knight Rises                           636800000  2012
# The Hunger Games: Catching Fire                 440300000  2013
# Jurassic World: Fallen Kingdom                  891800000  2018
# Toy Story 3                                     652000000  2010
# Wonder Woman                                    409300000  2017
# Iron Man 3                                      805800000  2013
# Captain America: Civil War                      745200000  2016
# The Hunger Games                                286400000  2012
# Jumanji: Welcome to the Jungle                  557600000  2017
# Frozen                                          875700000  2013
# Guardians of the Galaxy Vol. 2                  473900000  2017
# Harry Potter and the Deathly Hallows Part 2     960500000  2011
# The Secret Life of Pets                         507100000  2016
# Despicable Me 2                                 602700000  2013
# The Jungle Book (2016)                          602500000  2016
# Deadpool                                        420000000  2016
# Inside Out                                      501100000  2015
# Furious 7                                         1,163.0  2015
# Transformers: Dark of the Moon                  771400000  2011

# %%
# Getting descriptive statistics on the sorted domestic movie gross data set.
sorted_movie_gross_domestic_df.describe()
# Out:
#        domestic_gross  year
# count            3359  3359
# mean         28745845  2014
# std          66982498     2
# min               100  2010
# 25%            120000  2012
# 50%           1400000  2014
# 75%          27900000  2016
# max         936700000  2018

# %%
conn = sqlite3.connect('data/im.db')
cur = conn.cursor()
imdb_tables = pd.read_sql('SELECT * FROM sqlite_master WHERE type = "table"', conn)
imdb_tables
# Out:
#     type           name       tbl_name  rootpage  \
# 0  table   movie_basics   movie_basics         2
# 1  table      directors      directors         3
# 2  table      known_for      known_for         4
# 3  table     movie_akas     movie_akas         5
# 4  table  movie_ratings  movie_ratings         6
# 5  table        persons        persons         7
# 6  table     principals     principals         8
# 7  table        writers        writers         9
#
#                                                  sql
# 0  CREATE TABLE "movie_basics" (\n"movie_id" TEXT...
# 1  CREATE TABLE "directors" (\n"movie_id" TEXT,\n...
# 2  CREATE TABLE "known_for" (\n"person_id" TEXT,\...
# 3  CREATE TABLE "movie_akas" (\n"movie_id" TEXT,\...
# 4  CREATE TABLE "movie_ratings" (\n"movie_id" TEX...
# 5  CREATE TABLE "persons" (\n"person_id" TEXT,\n ...
# 6  CREATE TABLE "principals" (\n"movie_id" TEXT,\...
# 7  CREATE TABLE "writers" (\n"movie_id" TEXT,\n  ...

# %%
# read in the movie_basics table into a dataframe
movie_basics = pd.read_sql_query("SELECT * from movie_basics", conn)

# read in the directors table into a dataframe
directors = pd.read_sql_query("SELECT * from directors", conn)

# %%
# deleting duplicate entries in the dataframe.
directors.drop_duplicates(subset=['movie_id'], keep='first', inplace=True)

# %%
directors
# Out:
#          movie_id   person_id
# 0       tt0285252   nm0899854
# 1       tt0462036   nm1940585
# 2       tt0835418   nm0151540
# 4       tt0878654   nm0089502
# 7       tt0879859   nm2416460
# ...           ...         ...
# 291167  tt8999892  nm10122247
# 291169  tt8999974  nm10122357
# 291170  tt9001390   nm6711477
# 291171  tt9001494  nm10123242
# 291173  tt9004986   nm4993825
#
# [140417 rows x 2 columns]

# %%
# Merge the movie basics and directors tables on the movie_id column
movie_directors = pd.merge(movie_basics, directors, on='movie_id', how='left')

# %%
movie_directors
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres   person_id
# 0                   175    Action,Crime,Drama   nm0712540
# 1                   114       Biography,Drama   nm0002411
# 2                   122                 Drama   nm0000080
# 3                   nan          Comedy,Drama   nm0611531
# 4                    80  Comedy,Drama,Fantasy   nm0765384
# ...                 ...                   ...         ...
# 146139              123                 Drama   nm8185151
# 146140              nan           Documentary   nm9272490
# 146141              nan                Comedy   nm7764440
# 146142              116                  None  nm10538612
# 146143              nan           Documentary   nm9272490
#
# [146144 rows x 7 columns]

# %%
persons = pd.read_sql_query("SELECT * from persons", conn)

# %%
df_imdb = pd.read_sql('SELECT * FROM persons', conn)

# %%
# Merge the directors table with the persons table
directors_persons = pd.merge(directors, persons, on='person_id', how='inner')

# Merge the resulting dataframe with the movie basics table
movie_directors_df = pd.merge(movie_directors, directors_persons, on='person_id', how='left')

movie_directors_df
# Out:
#        movie_id_x                    primary_title  \
# 0       tt0063540                        Sunghursh
# 1       tt0066787  One Day Before the Rainy Season
# 2       tt0069049       The Other Side of the Wind
# 3       tt0069204                  Sabse Bada Sukh
# 4       tt0100275         The Wandering Soap Opera
# ...           ...                              ...
# 380129  tt9916754   Chico Albuquerque - Revelações
# 380130  tt9916754   Chico Albuquerque - Revelações
# 380131  tt9916754   Chico Albuquerque - Revelações
# 380132  tt9916754   Chico Albuquerque - Revelações
# 380133  tt9916754   Chico Albuquerque - Revelações
#
#                         original_title  start_year  runtime_minutes  \
# 0                            Sunghursh        2013              175
# 1                      Ashad Ka Ek Din        2019              114
# 2           The Other Side of the Wind        2018              122
# 3                      Sabse Bada Sukh        2018              nan
# 4                La Telenovela Errante        2017               80
# ...                                ...         ...              ...
# 380129  Chico Albuquerque - Revelações        2013              nan
# 380130  Chico Albuquerque - Revelações        2013              nan
# 380131  Chico Albuquerque - Revelações        2013              nan
# 380132  Chico Albuquerque - Revelações        2013              nan
# 380133  Chico Albuquerque - Revelações        2013              nan
#
#                       genres  person_id  movie_id_y          primary_name  \
# 0         Action,Crime,Drama  nm0712540   tt0063540   Harnam Singh Rawail
# 1            Biography,Drama  nm0002411   tt0066787             Mani Kaul
# 2                      Drama  nm0000080   tt0069049          Orson Welles
# 3               Comedy,Drama  nm0611531   tt0069204  Hrishikesh Mukherjee
# 4       Comedy,Drama,Fantasy  nm0765384   tt1928329     Valeria Sarmiento
# ...                      ...        ...         ...                   ...
# 380129           Documentary  nm9272490  tt10225752         Angela Gurgel
# 380130           Documentary  nm9272490   tt9916754         Angela Gurgel
# 380131           Documentary  nm9272490  tt10231530         Angela Gurgel
# 380132           Documentary  nm9272490  tt10056270         Angela Gurgel
# 380133           Documentary  nm9272490  tt10006546         Angela Gurgel
#
#         birth_year  death_year        primary_profession
# 0             1921        2004  director,writer,producer
# 1             1944        2011     director,writer,actor
# 2             1915        1985     actor,director,writer
# 3             1922        2006    director,editor,writer
# 4             1948         nan    editor,director,writer
# ...            ...         ...                       ...
# 380129         nan         nan           director,writer
# 380130         nan         nan           director,writer
# 380131         nan         nan           director,writer
# 380132         nan         nan           director,writer
# 380133         nan         nan           director,writer
#
# [380134 rows x 12 columns]

# %%
dir_name_title = movie_directors_df[['movie_id_x', 'primary_title', 'person_id', 'primary_name']]
dir_name_title
# Out:
#        movie_id_x                    primary_title  person_id  \
# 0       tt0063540                        Sunghursh  nm0712540
# 1       tt0066787  One Day Before the Rainy Season  nm0002411
# 2       tt0069049       The Other Side of the Wind  nm0000080
# 3       tt0069204                  Sabse Bada Sukh  nm0611531
# 4       tt0100275         The Wandering Soap Opera  nm0765384
# ...           ...                              ...        ...
# 380129  tt9916754   Chico Albuquerque - Revelações  nm9272490
# 380130  tt9916754   Chico Albuquerque - Revelações  nm9272490
# 380131  tt9916754   Chico Albuquerque - Revelações  nm9272490
# 380132  tt9916754   Chico Albuquerque - Revelações  nm9272490
# 380133  tt9916754   Chico Albuquerque - Revelações  nm9272490
#
#                 primary_name
# 0        Harnam Singh Rawail
# 1                  Mani Kaul
# 2               Orson Welles
# 3       Hrishikesh Mukherjee
# 4          Valeria Sarmiento
# ...                      ...
# 380129         Angela Gurgel
# 380130         Angela Gurgel
# 380131         Angela Gurgel
# 380132         Angela Gurgel
# 380133         Angela Gurgel
#
# [380134 rows x 4 columns]

# %%
budget_info = movie_budgets_df[['movie', 'production_budget', 'domestic_gross', 'worldwide_gross']]
budget_info
# Out:
#                                           movie  production_budget  \
# id
# 1                                        Avatar          425000000
# 2   Pirates of the Caribbean: On Stranger Tides          410600000
# 3                                  Dark Phoenix          350000000
# 4                       Avengers: Age of Ultron          330600000
# 5             Star Wars Ep. VIII: The Last Jedi          317000000
# ..                                          ...                ...
# 78                                       Red 11               7000
# 79                                    Following               6000
# 80                Return to the Land of Wonders               5000
# 81                         A Plague So Pleasant               1400
# 82                            My Date With Drew               1100
#
#     domestic_gross  worldwide_gross
# id
# 1        760507625       2776345279
# 2        241063875       1045663875
# 3         42762350        149762350
# 4        459005868       1403013963
# 5        620181382       1316721747
# ..             ...              ...
# 78               0                0
# 79           48482           240495
# 80            1338             1338
# 81               0                0
# 82          181041           181041
#
# [5782 rows x 4 columns]

# %%
budget_info.rename(columns={"movie": "primary_title"}, inplace=True)

# %%
budget_info
# Out:
#                                   primary_title  production_budget  \
# id
# 1                                        Avatar          425000000
# 2   Pirates of the Caribbean: On Stranger Tides          410600000
# 3                                  Dark Phoenix          350000000
# 4                       Avengers: Age of Ultron          330600000
# 5             Star Wars Ep. VIII: The Last Jedi          317000000
# ..                                          ...                ...
# 78                                       Red 11               7000
# 79                                    Following               6000
# 80                Return to the Land of Wonders               5000
# 81                         A Plague So Pleasant               1400
# 82                            My Date With Drew               1100
#
#     domestic_gross  worldwide_gross
# id
# 1        760507625       2776345279
# 2        241063875       1045663875
# 3         42762350        149762350
# 4        459005868       1403013963
# 5        620181382       1316721747
# ..             ...              ...
# 78               0                0
# 79           48482           240495
# 80            1338             1338
# 81               0                0
# 82          181041           181041
#
# [5782 rows x 4 columns]

# %%
gross_directors_df = pd.merge(dir_name_title, budget_info, on='primary_title', how='inner')

# %% [markdown]
# I wanted to calculate "profit" and wanted to make a new column to get a sense for what films were making the most money.I did this by taking gross and subtracting production budget in the dataframe.

# %%
gross_directors_df['profit'] = gross_directors_df['worldwide_gross'] - gross_directors_df['production_budget']
gross_directors_df
# Out:
#       movie_id_x  primary_title  person_id       primary_name  \
# 0      tt0249516     Foodfight!  nm0440415  Lawrence Kasanoff
# 1      tt0249516     Foodfight!  nm0440415  Lawrence Kasanoff
# 2      tt0293429  Mortal Kombat  nm2585406      Simon McQuoid
# 3      tt0326592  The Overnight  nm1208371     Jed I. Goodman
# 4      tt3844362  The Overnight  nm2674307      Patrick Brice
# ...          ...            ...        ...                ...
# 10924  tt9844102            Ray  nm3386933    Riingo Banerjee
# 10925  tt9844102            Ray  nm3386933    Riingo Banerjee
# 10926  tt9844102            Ray  nm3386933    Riingo Banerjee
# 10927  tt9893078        Sublime  nm0349702     Bill Guttentag
# 10928  tt9893078        Sublime  nm0349702     Bill Guttentag
#
#        production_budget  domestic_gross  worldwide_gross     profit
# 0               45000000               0            73706  -44926294
# 1               45000000               0            73706  -44926294
# 2               20000000        70433227        122133227  102133227
# 3                 200000         1109808          1165996     965996
# 4                 200000         1109808          1165996     965996
# ...                  ...             ...              ...        ...
# 10924           40000000        75305995        124823094   84823094
# 10925           40000000        75305995        124823094   84823094
# 10926           40000000        75305995        124823094   84823094
# 10927            1800000               0                0   -1800000
# 10928            1800000               0                0   -1800000
#
# [10929 rows x 8 columns]

# %%
sorted_gross_directors_df = gross_directors_df.sort_values(by='worldwide_gross', ascending=False)

# %%
sorted_gross_directors_df.head(30)
# Out:
#      movie_id_x            primary_title   person_id     primary_name  \
# 4972  tt1775309                   Avatar   nm3786927     Atsushi Wada
# 4973  tt1775309                   Avatar   nm3786927     Atsushi Wada
# 4974  tt1775309                   Avatar   nm3786927     Atsushi Wada
# 7887  tt2495766                  Titanic   nm4430776       Pete Meads
# 7888  tt8852130                  Titanic  nm10047650        Ravi Punj
# 9621  tt4154756   Avengers: Infinity War   nm0751577    Anthony Russo
# 9622  tt4154756   Avengers: Infinity War   nm0751577    Anthony Russo
# 9625  tt4154756   Avengers: Infinity War   nm0751577    Anthony Russo
# 9623  tt4154756   Avengers: Infinity War   nm0751577    Anthony Russo
# 9624  tt4154756   Avengers: Infinity War   nm0751577    Anthony Russo
# 31    tt0369610           Jurassic World   nm1119880  Colin Trevorrow
# 30    tt0369610           Jurassic World   nm1119880  Colin Trevorrow
# 28    tt0369610           Jurassic World   nm1119880  Colin Trevorrow
# 29    tt0369610           Jurassic World   nm1119880  Colin Trevorrow
# 8347  tt2820852                Furious 7   nm1490123        James Wan
# 8353  tt2820852                Furious 7   nm1490123        James Wan
# 8352  tt2820852                Furious 7   nm1490123        James Wan
# 8350  tt2820852                Furious 7   nm1490123        James Wan
# 8349  tt2820852                Furious 7   nm1490123        James Wan
# 8348  tt2820852                Furious 7   nm1490123        James Wan
# 8351  tt2820852                Furious 7   nm1490123        James Wan
# 395   tt0848228             The Avengers   nm0923736      Joss Whedon
# 393   tt0848228             The Avengers   nm0923736      Joss Whedon
# 391   tt0848228             The Avengers   nm0923736      Joss Whedon
# 7712  tt2395427  Avengers: Age of Ultron   nm0923736      Joss Whedon
# 7713  tt2395427  Avengers: Age of Ultron   nm0923736      Joss Whedon
# 7711  tt2395427  Avengers: Age of Ultron   nm0923736      Joss Whedon
# 5227  tt1825683            Black Panther   nm3363032     Ryan Coogler
# 5226  tt1825683            Black Panther   nm3363032     Ryan Coogler
# 5228  tt1825683            Black Panther   nm3363032     Ryan Coogler
#
#       production_budget  domestic_gross  worldwide_gross      profit
# 4972          425000000       760507625       2776345279  2351345279
# 4973          425000000       760507625       2776345279  2351345279
# 4974          425000000       760507625       2776345279  2351345279
# 7887          200000000       659363944       2208208395  2008208395
# 7888          200000000       659363944       2208208395  2008208395
# 9621          300000000       678815482       2048134200  1748134200
# 9622          300000000       678815482       2048134200  1748134200
# 9625          300000000       678815482       2048134200  1748134200
# 9623          300000000       678815482       2048134200  1748134200
# 9624          300000000       678815482       2048134200  1748134200
# 31            215000000       652270625       1648854864  1433854864
# 30            215000000       652270625       1648854864  1433854864
# 28            215000000       652270625       1648854864  1433854864
# 29            215000000       652270625       1648854864  1433854864
# 8347          190000000       353007020       1518722794  1328722794
# 8353          190000000       353007020       1518722794  1328722794
# 8352          190000000       353007020       1518722794  1328722794
# 8350          190000000       353007020       1518722794  1328722794
# 8349          190000000       353007020       1518722794  1328722794
# 8348          190000000       353007020       1518722794  1328722794
# 8351          190000000       353007020       1518722794  1328722794
# 395           225000000       623279547       1517935897  1292935897
# 393           225000000       623279547       1517935897  1292935897
# 391           225000000       623279547       1517935897  1292935897
# 7712          330600000       459005868       1403013963  1072413963
# 7713          330600000       459005868       1403013963  1072413963
# 7711          330600000       459005868       1403013963  1072413963
# 5227          200000000       700059566       1348258224  1148258224
# 5226          200000000       700059566       1348258224  1148258224
# 5228          200000000       700059566       1348258224  1148258224

# %%
# Convert the data type of 'id' column in the second dataframe
sorted_popularity_tmdb_movies_df['id'] = sorted_popularity_tmdb_movies_df['id'].astype(str)

# Perform the merge operation
genre_directors_df = sorted_gross_directors_df.merge(sorted_popularity_tmdb_movies_df[['id', 'genre_ids']], left_on='movie_id_x', right_on='id', how='left')

# Drop the duplicate 'id' column
genre_directors_df.drop('id', axis=1, inplace=True)

# %%
# Perform a merge operation
genre_directors_df = sorted_gross_directors_df.merge(sorted_popularity_tmdb_movies_df[['id', 'genre_ids']], left_on='movie_id_x', right_on='id', how='left')

# Drop the duplicate 'id' column
genre_directors_df.drop('id', axis=1, inplace=True)

# %%
genre_directors_df.head(50)
# Out:
#    movie_id_x                   primary_title   person_id     primary_name  \
# 0   tt1775309                          Avatar   nm3786927     Atsushi Wada
# 1   tt1775309                          Avatar   nm3786927     Atsushi Wada
# 2   tt1775309                          Avatar   nm3786927     Atsushi Wada
# 3   tt2495766                         Titanic   nm4430776       Pete Meads
# 4   tt8852130                         Titanic  nm10047650        Ravi Punj
# 5   tt4154756          Avengers: Infinity War   nm0751577    Anthony Russo
# 6   tt4154756          Avengers: Infinity War   nm0751577    Anthony Russo
# 7   tt4154756          Avengers: Infinity War   nm0751577    Anthony Russo
# 8   tt4154756          Avengers: Infinity War   nm0751577    Anthony Russo
# 9   tt4154756          Avengers: Infinity War   nm0751577    Anthony Russo
# 10  tt0369610                  Jurassic World   nm1119880  Colin Trevorrow
# 11  tt0369610                  Jurassic World   nm1119880  Colin Trevorrow
# 12  tt0369610                  Jurassic World   nm1119880  Colin Trevorrow
# 13  tt0369610                  Jurassic World   nm1119880  Colin Trevorrow
# 14  tt2820852                       Furious 7   nm1490123        James Wan
# 15  tt2820852                       Furious 7   nm1490123        James Wan
# 16  tt2820852                       Furious 7   nm1490123        James Wan
# 17  tt2820852                       Furious 7   nm1490123        James Wan
# 18  tt2820852                       Furious 7   nm1490123        James Wan
# 19  tt2820852                       Furious 7   nm1490123        James Wan
# 20  tt2820852                       Furious 7   nm1490123        James Wan
# 21  tt0848228                    The Avengers   nm0923736      Joss Whedon
# 22  tt0848228                    The Avengers   nm0923736      Joss Whedon
# 23  tt0848228                    The Avengers   nm0923736      Joss Whedon
# 24  tt2395427         Avengers: Age of Ultron   nm0923736      Joss Whedon
# 25  tt2395427         Avengers: Age of Ultron   nm0923736      Joss Whedon
# 26  tt2395427         Avengers: Age of Ultron   nm0923736      Joss Whedon
# 27  tt1825683                   Black Panther   nm3363032     Ryan Coogler
# 28  tt1825683                   Black Panther   nm3363032     Ryan Coogler
# 29  tt1825683                   Black Panther   nm3363032     Ryan Coogler
# 30  tt4881806  Jurassic World: Fallen Kingdom   nm1291105      J.A. Bayona
# 31  tt4881806  Jurassic World: Fallen Kingdom   nm1291105      J.A. Bayona
# 32  tt4881806  Jurassic World: Fallen Kingdom   nm1291105      J.A. Bayona
# 33  tt1323045                          Frozen   nm1697112       Adam Green
# 34  tt1323045                          Frozen   nm1697112       Adam Green
# 35  tt1323045                          Frozen   nm1697112       Adam Green
# 36  tt1323045                          Frozen   nm1697112       Adam Green
# 37  tt1323045                          Frozen   nm1697112       Adam Green
# 38  tt1611845                          Frozen   nm0477213     Chi-kin Kwok
# 39  tt1611845                          Frozen   nm0477213     Chi-kin Kwok
# 40  tt1611845                          Frozen   nm0477213     Chi-kin Kwok
# 41  tt2294629                          Frozen   nm0118333       Chris Buck
# 42  tt2294629                          Frozen   nm0118333       Chris Buck
# 43  tt9173998            Beauty and the Beast  nm10211048      Zane Burden
# 44  tt2771200            Beauty and the Beast   nm0174374      Bill Condon
# 45  tt2771200            Beauty and the Beast   nm0174374      Bill Condon
# 46  tt2771200            Beauty and the Beast   nm0174374      Bill Condon
# 47  tt2316801            Beauty and the Beast   nm0304521  Christophe Gans
# 48  tt2771200            Beauty and the Beast   nm0174374      Bill Condon
# 49  tt2771200            Beauty and the Beast   nm0174374      Bill Condon
#
#     production_budget  domestic_gross  worldwide_gross      profit genre_ids
# 0           425000000       760507625       2776345279  2351345279       NaN
# 1           425000000       760507625       2776345279  2351345279       NaN
# 2           425000000       760507625       2776345279  2351345279       NaN
# 3           200000000       659363944       2208208395  2008208395       NaN
# 4           200000000       659363944       2208208395  2008208395       NaN
# 5           300000000       678815482       2048134200  1748134200       NaN
# 6           300000000       678815482       2048134200  1748134200       NaN
# 7           300000000       678815482       2048134200  1748134200       NaN
# 8           300000000       678815482       2048134200  1748134200       NaN
# 9           300000000       678815482       2048134200  1748134200       NaN
# 10          215000000       652270625       1648854864  1433854864       NaN
# 11          215000000       652270625       1648854864  1433854864       NaN
# 12          215000000       652270625       1648854864  1433854864       NaN
# 13          215000000       652270625       1648854864  1433854864       NaN
# 14          190000000       353007020       1518722794  1328722794       NaN
# 15          190000000       353007020       1518722794  1328722794       NaN
# 16          190000000       353007020       1518722794  1328722794       NaN
# 17          190000000       353007020       1518722794  1328722794       NaN
# 18          190000000       353007020       1518722794  1328722794       NaN
# 19          190000000       353007020       1518722794  1328722794       NaN
# 20          190000000       353007020       1518722794  1328722794       NaN
# 21          225000000       623279547       1517935897  1292935897       NaN
# 22          225000000       623279547       1517935897  1292935897       NaN
# 23          225000000       623279547       1517935897  1292935897       NaN
# 24          330600000       459005868       1403013963  1072413963       NaN
# 25          330600000       459005868       1403013963  1072413963       NaN
# 26          330600000       459005868       1403013963  1072413963       NaN
# 27          200000000       700059566       1348258224  1148258224       NaN
# 28          200000000       700059566       1348258224  1148258224       NaN
# 29          200000000       700059566       1348258224  1148258224       NaN
# 30          170000000       417719760       1305772799  1135772799       NaN
# 31          170000000       417719760       1305772799  1135772799       NaN
# 32          170000000       417719760       1305772799  1135772799       NaN
# 33          150000000       400738009       1272469910  1122469910       NaN
# 34          150000000       400738009       1272469910  1122469910       NaN
# 35          150000000       400738009       1272469910  1122469910       NaN
# 36          150000000       400738009       1272469910  1122469910       NaN
# 37          150000000       400738009       1272469910  1122469910       NaN
# 38          150000000       400738009       1272469910  1122469910       NaN
# 39          150000000       400738009       1272469910  1122469910       NaN
# 40          150000000       400738009       1272469910  1122469910       NaN
# 41          150000000       400738009       1272469910  1122469910       NaN
# 42          150000000       400738009       1272469910  1122469910       NaN
# 43          160000000       504014165       1259199706  1099199706       NaN
# 44          160000000       504014165       1259199706  1099199706       NaN
# 45          160000000       504014165       1259199706  1099199706       NaN
# 46          160000000       504014165       1259199706  1099199706       NaN
# 47          160000000       504014165       1259199706  1099199706       NaN
# 48          160000000       504014165       1259199706  1099199706       NaN
# 49          160000000       504014165       1259199706  1099199706       NaN

# %% [markdown]
# I wanted to check if there were any duplicate entries in the dataframe.

# %%
sorted_gross_directors_df.info
# Out:
# <bound method DataFrame.info of       movie_id_x             primary_title   person_id    primary_name  \
# 4972   tt1775309                    Avatar   nm3786927    Atsushi Wada
# 4973   tt1775309                    Avatar   nm3786927    Atsushi Wada
# 4974   tt1775309                    Avatar   nm3786927    Atsushi Wada
# 7887   tt2495766                   Titanic   nm4430776      Pete Meads
# 7888   tt8852130                   Titanic  nm10047650       Ravi Punj
# ...          ...                       ...         ...             ...
# 5340   tt1836212  All Superheroes Must Die   nm1875808     Jason Trost
# 5339   tt1836212  All Superheroes Must Die   nm1875808     Jason Trost
# 5338   tt1836212  All Superheroes Must Die   nm1875808     Jason Trost
# 5258   tt1827354                  Airborne   nm2403079   Dominic Burns
# 10928  tt9893078                   Sublime   nm0349702  Bill Guttentag
#
#        production_budget  domestic_gross  worldwide_gross      profit
# 4972           425000000       760507625       2776345279  2351345279
# 4973           425000000       760507625       2776345279  2351345279
# 4974           425000000       760507625       2776345279  2351345279
# 7887           200000000       659363944       2208208395  2008208395
# 7888           200000000       659363944       2208208395  2008208395
# ...                  ...             ...              ...         ...
# 5340               20000               0                0      -20000
# 5339               20000               0                0      -20000
# 5338               20000               0                0      -20000
# 5258             1200000               0                0    -1200000
# 10928            1800000               0                0    -1800000
#
# [10929 rows x 8 columns]>

# %%
# I wanted to drop duplicates in the below dataframe.
sorted_gross_directors_df.drop_duplicates(subset=['movie_id_x', 'person_id'], inplace=True)

# %%
sorted_gross_directors_df.head(60)
# Out:
#       movie_id_x                                primary_title   person_id  \
# 4972   tt1775309                                       Avatar   nm3786927
# 7887   tt2495766                                      Titanic   nm4430776
# 7888   tt8852130                                      Titanic  nm10047650
# 9621   tt4154756                       Avengers: Infinity War   nm0751577
# 31     tt0369610                               Jurassic World   nm1119880
# 8347   tt2820852                                    Furious 7   nm1490123
# 395    tt0848228                                 The Avengers   nm0923736
# 7712   tt2395427                      Avengers: Age of Ultron   nm0923736
# 5227   tt1825683                                Black Panther   nm3363032
# 10014  tt4881806               Jurassic World: Fallen Kingdom   nm1291105
# 2425   tt1323045                                       Frozen   nm1697112
# 2427   tt1611845                                       Frozen   nm0477213
# 2430   tt2294629                                       Frozen   nm0118333
# 7472   tt9173998                         Beauty and the Beast  nm10211048
# 7470   tt2771200                         Beauty and the Beast   nm0174374
# 7458   tt2316801                         Beauty and the Beast   nm0304521
# 9169   tt3606756                                Incredibles 2   nm0083348
# 9889   tt4630562                      The Fate of the Furious   nm0336620
# 2325   tt1300854                                   Iron Man 3   nm0000948
# 7357   tt2293640                                      Minions   nm1853544
# 3157   tt1477834                                      Aquaman   nm1490123
# 9021   tt3498820                   Captain America: Civil War   nm0751577
# 2737   tt1399103               Transformers: Dark of the Moon   nm0000881
# 9620   tt4154664                               Captain Marvel   nm0281396
# 1568   tt1074638                                      Skyfall   nm0005222
# 6632   tt2109248              Transformers: Age of Extinction   nm0000881
# 2509   tt1345836                        The Dark Knight Rises   nm0634240
# 70     tt0435761                                  Toy Story 3   nm0881279
# 9294   tt3748528                 Rogue One: A Star Wars Story   nm2284484
# 2320   tt1298650  Pirates of the Caribbean: On Stranger Tides   nm0551128
# 8988   tt3469046                              Despicable Me 3   nm0049633
# 860    tt2049386                          Alice in Wonderland   nm0288188
# 848    tt1926979                          Alice in Wonderland   nm2483359
# 844    tt1014759                          Alice in Wonderland   nm0000318
# 7323   tt2277860                                 Finding Dory   nm0004056
# 8475   tt2948356                                     Zootopia   nm1158544
# 443    tt0903624            The Hobbit: An Unexpected Journey   nm0001392
# 10465  tt6105098                                The Lion King   nm0269463
# 4502   tt1690953                              Despicable Me 2   nm1853544
# 7341   tt2283362               Jumanji: Welcome to the Jungle   nm0440458
# 7112   tt3040964                              The Jungle Book   nm0269463
# 7100   tt2226178                              The Jungle Book   nm0266255
# 1798   tt1170358          The Hobbit: The Desolation of Smaug   nm0001392
# 7425   tt2310332    The Hobbit: The Battle of the Five Armies   nm0001392
# 4758   tt1727824                            Bohemian Rhapsody   nm0001741
# 8237   tt2709768                      The Secret Life of Pets   nm0719208
# 7224   tt2250912                       Spider-Man: Homecoming   nm1218281
# 4409   tt1667889                   Ice Age: Continental Drift   nm0862211
# 7637   tt2379713                                      Spectre   nm0005222
# 8511   tt2975590           Batman v Superman: Dawn of Justice   nm0811583
# 5897   tt1951264              The Hunger Games: Catching Fire   nm1349376
# 4190   tt8269544                                   Inside Out   nm3970750
# 4186   tt2096673                                   Inside Out   nm0230032
# 4182   tt1865538                                   Inside Out   nm4341391
# 4179   tt1640486                                   Inside Out   nm0541703
# 4183   tt2064820                                   Inside Out   nm3034358
# 4189   tt6419446                                   Inside Out         NaN
# 4188   tt2608638                                   Inside Out   nm3322414
# 4184   tt2071483                                   Inside Out         NaN
# 2163   tt1270797                                        Venom   nm0281508
#
#             primary_name  production_budget  domestic_gross  worldwide_gross  \
# 4972        Atsushi Wada          425000000       760507625       2776345279
# 7887          Pete Meads          200000000       659363944       2208208395
# 7888           Ravi Punj          200000000       659363944       2208208395
# 9621       Anthony Russo          300000000       678815482       2048134200
# 31       Colin Trevorrow          215000000       652270625       1648854864
# 8347           James Wan          190000000       353007020       1518722794
# 395          Joss Whedon          225000000       623279547       1517935897
# 7712         Joss Whedon          330600000       459005868       1403013963
# 5227        Ryan Coogler          200000000       700059566       1348258224
# 10014        J.A. Bayona          170000000       417719760       1305772799
# 2425          Adam Green          150000000       400738009       1272469910
# 2427        Chi-kin Kwok          150000000       400738009       1272469910
# 2430          Chris Buck          150000000       400738009       1272469910
# 7472         Zane Burden          160000000       504014165       1259199706
# 7470         Bill Condon          160000000       504014165       1259199706
# 7458     Christophe Gans          160000000       504014165       1259199706
# 9169           Brad Bird          200000000       608581744       1242520711
# 9889        F. Gary Gray          250000000       225764765       1234846267
# 2325         Shane Black          200000000       408992272       1215392272
# 7357       Pierre Coffin           74000000       336045770       1160336173
# 3157           James Wan          160000000       335061807       1146894640
# 9021       Anthony Russo          250000000       408084349       1140069413
# 2737         Michael Bay          195000000       352390543       1123790543
# 9620          Ryan Fleck          175000000       426525952       1123061550
# 1568          Sam Mendes          200000000       304360277       1110526981
# 6632         Michael Bay          210000000       245439076       1104039076
# 2509   Christopher Nolan          275000000       448139099       1084439099
# 70           Lee Unkrich          200000000       415004880       1068879522
# 9294      Gareth Edwards          200000000       532177324       1049102856
# 2320        Rob Marshall          410600000       241063875       1045663875
# 8988          Kyle Balda           75000000       264624300       1034727750
# 860     James Fotopoulos          200000000       334191110       1025491110
# 848    Giuseppe Malpasso          200000000       334191110       1025491110
# 844           Tim Burton          200000000       334191110       1025491110
# 7323      Andrew Stanton          200000000       486295561       1021215193
# 8475          Jared Bush          150000000       341268248       1019429616
# 443        Peter Jackson          250000000       303003568       1017003568
# 10465        Jon Favreau           79300000       421785283        986214868
# 4502       Pierre Coffin           76000000       368065385        975216835
# 7341         Jake Kasdan           90000000       404508916        964496193
# 7112         Jon Favreau          175000000       364001123        962854547
# 7100     Jun Falkenstein          175000000       364001123        962854547
# 1798       Peter Jackson          250000000       258366855        960366855
# 7425       Peter Jackson          250000000       255119788        945577621
# 4758        Bryan Singer           55000000       216303339        894985342
# 8237        Chris Renaud           75000000       368384330        886750534
# 7224           Jon Watts          175000000       334201140        880166350
# 4409      Mike Thurmeier           95000000       161321843        879765137
# 7637          Sam Mendes          300000000       200074175        879620923
# 8511         Zack Snyder          250000000       330360194        867500281
# 5897    Francis Lawrence          130000000       424668047        864868047
# 4190    Russell Davidson          175000000       356461711        854235992
# 4186         Pete Docter          175000000       356461711        854235992
# 4182      Vaggelis Rigas          175000000       356461711        854235992
# 4179    Artie Mandelberg          175000000       356461711        854235992
# 4183         Nasir Rahim          175000000       356461711        854235992
# 4189                 NaN          175000000       356461711        854235992
# 4188    Alastair Siddons          175000000       356461711        854235992
# 4184                 NaN          175000000       356461711        854235992
# 2163     Ruben Fleischer          116000000       213511408        853628605
#
#            profit
# 4972   2351345279
# 7887   2008208395
# 7888   2008208395
# 9621   1748134200
# 31     1433854864
# 8347   1328722794
# 395    1292935897
# 7712   1072413963
# 5227   1148258224
# 10014  1135772799
# 2425   1122469910
# 2427   1122469910
# 2430   1122469910
# 7472   1099199706
# 7470   1099199706
# 7458   1099199706
# 9169   1042520711
# 9889    984846267
# 2325   1015392272
# 7357   1086336173
# 3157    986894640
# 9021    890069413
# 2737    928790543
# 9620    948061550
# 1568    910526981
# 6632    894039076
# 2509    809439099
# 70      868879522
# 9294    849102856
# 2320    635063875
# 8988    959727750
# 860     825491110
# 848     825491110
# 844     825491110
# 7323    821215193
# 8475    869429616
# 443     767003568
# 10465   906914868
# 4502    899216835
# 7341    874496193
# 7112    787854547
# 7100    787854547
# 1798    710366855
# 7425    695577621
# 4758    839985342
# 8237    811750534
# 7224    705166350
# 4409    784765137
# 7637    579620923
# 8511    617500281
# 5897    734868047
# 4190    679235992
# 4186    679235992
# 4182    679235992
# 4179    679235992
# 4183    679235992
# 4189    679235992
# 4188    679235992
# 4184    679235992
# 2163    737628605

# %%
directors_persons
# Out:
#          movie_id   person_id       primary_name  birth_year  death_year  \
# 0       tt0285252   nm0899854        Tony Vitale        1964         nan
# 1       tt0462036   nm1940585         Bill Haley         nan         nan
# 2       tt0835418   nm0151540  Jay Chandrasekhar        1968         nan
# 3       tt0859635   nm0151540  Jay Chandrasekhar        1968         nan
# 4       tt0878654   nm0089502        Albert Pyun        1954         nan
# ...           ...         ...                ...         ...         ...
# 140411  tt8998302  nm10121510        Daryl Boman         nan         nan
# 140412  tt8999892  nm10122247    C. Damon Adcock         nan         nan
# 140413  tt8999974  nm10122357      Daysi Burbano         nan         nan
# 140414  tt9001390   nm6711477      Bernard Lessa         nan         nan
# 140415  tt9001494  nm10123242          Tate Nova         nan         nan
#
#                      primary_profession
# 0              producer,director,writer
# 1              director,writer,producer
# 2                 director,actor,writer
# 3                 director,actor,writer
# 4              director,writer,producer
# ...                                 ...
# 140411         producer,director,writer
# 140412                             None
# 140413  director,writer,cinematographer
# 140414  director,writer,cinematographer
# 140415                director,producer
#
# [140416 rows x 6 columns]

# %%
# Calling movie_directors df
len(movie_directors['primary_title'].unique())
# Out:
# 136071

# %%
movie_directors
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres   person_id
# 0                   175    Action,Crime,Drama   nm0712540
# 1                   114       Biography,Drama   nm0002411
# 2                   122                 Drama   nm0000080
# 3                   nan          Comedy,Drama   nm0611531
# 4                    80  Comedy,Drama,Fantasy   nm0765384
# ...                 ...                   ...         ...
# 146139              123                 Drama   nm8185151
# 146140              nan           Documentary   nm9272490
# 146141              nan                Comedy   nm7764440
# 146142              116                  None  nm10538612
# 146143              nan           Documentary   nm9272490
#
# [146144 rows x 7 columns]

# %%
movie_basics = pd.read_sql_query("SELECT * from movie_basics", conn)

# read in the directors table into a dataframe
directors = pd.read_sql_query("SELECT * from directors", conn)

# join the two dataframes on the movie_id column
df = pd.merge(movie_basics, directors, on="movie_id")

# close the database connection
conn.close()

# view the resulting dataframe
print(df.head())
# Out:
#     movie_id                    primary_title   original_title  start_year  \
# 0  tt0063540                        Sunghursh        Sunghursh        2013
# 1  tt0063540                        Sunghursh        Sunghursh        2013
# 2  tt0063540                        Sunghursh        Sunghursh        2013
# 3  tt0063540                        Sunghursh        Sunghursh        2013
# 4  tt0066787  One Day Before the Rainy Season  Ashad Ka Ek Din        2019
#
#    runtime_minutes              genres  person_id
# 0              175  Action,Crime,Drama  nm0712540
# 1              175  Action,Crime,Drama  nm0712540
# 2              175  Action,Crime,Drama  nm0712540
# 3              175  Action,Crime,Drama  nm0712540
# 4              114     Biography,Drama  nm0002411

# %%
# Establish a connection to the database
conn = sqlite3.connect('data/im.db')

# Execute the SQL query to join the tables and convert the result set into a DataFrame
df_imdb = pd.read_sql_query('SELECT * FROM directors JOIN persons ON directors.person_id = persons.person_id', conn)

# Preview the first 10 rows of the DataFrame
print(df_imdb.head(10))

# Close the connection
conn.close()
# Out:
#     movie_id  person_id  person_id       primary_name  birth_year  death_year  \
# 0  tt0285252  nm0899854  nm0899854        Tony Vitale        1964         nan
# 1  tt0462036  nm1940585  nm1940585         Bill Haley         nan         nan
# 2  tt0835418  nm0151540  nm0151540  Jay Chandrasekhar        1968         nan
# 3  tt0835418  nm0151540  nm0151540  Jay Chandrasekhar        1968         nan
# 4  tt0878654  nm0089502  nm0089502        Albert Pyun        1954         nan
# 5  tt0878654  nm2291498  nm2291498          Joe Baile         nan         nan
# 6  tt0878654  nm2292011  nm2292011       Howie Askins         nan         nan
# 7  tt0879859  nm2416460  nm2416460    Eric Manchester         nan         nan
# 8  tt0996958  nm2286991  nm2286991      Tara Cardinal        1978         nan
# 9  tt0996958  nm2286991  nm2286991      Tara Cardinal        1978         nan
#
#                     primary_profession
# 0             producer,director,writer
# 1             director,writer,producer
# 2                director,actor,writer
# 3                director,actor,writer
# 4             director,writer,producer
# 5  producer,director,camera_department
# 6      editor,director,cinematographer
# 7                      director,writer
# 8              actress,writer,producer
# 9              actress,writer,producer

# %%
# Establish a connection to the database
conn = sqlite3.connect('data/im.db')

# Execute the SQL query to join the tables and convert the result set into a DataFrame
df_imdb = pd.read_sql_query('SELECT * FROM directors JOIN movie_basics ON directors.movie_id = movie_basics.movie_id', conn)

# Preview the first 10 rows of the DataFrame
print(df_imdb.head(10))

# Close the connection
conn.close()
# Out:
#     movie_id  person_id   movie_id                    primary_title  \
# 0  tt0285252  nm0899854  tt0285252                   Life's a Beach
# 1  tt0462036  nm1940585  tt0462036  Steve Phoenix: The Untold Story
# 2  tt0835418  nm0151540  tt0835418                   The Babymakers
# 3  tt0835418  nm0151540  tt0835418                   The Babymakers
# 4  tt0878654  nm0089502  tt0878654                       Bulletface
# 5  tt0878654  nm2291498  tt0878654                       Bulletface
# 6  tt0878654  nm2292011  tt0878654                       Bulletface
# 7  tt0879859  nm2416460  tt0879859                             Torn
# 8  tt0996958  nm2286991  tt0996958         Legend of the Red Reaper
# 9  tt0996958  nm2286991  tt0996958         Legend of the Red Reaper
#
#                     original_title  start_year  runtime_minutes  \
# 0                   Life's a Beach        2012              100
# 1  Steve Phoenix: The Untold Story        2012              110
# 2                   The Babymakers        2012               95
# 3                   The Babymakers        2012               95
# 4                       Bulletface        2010               82
# 5                       Bulletface        2010               82
# 6                       Bulletface        2010               82
# 7                             Torn        2010              nan
# 8         Legend of the Red Reaper        2013               99
# 9         Legend of the Red Reaper        2013               99
#
#                      genres
# 0                    Comedy
# 1                     Drama
# 2                    Comedy
# 3                    Comedy
# 4                  Thriller
# 5                  Thriller
# 6                  Thriller
# 7                  Thriller
# 8  Action,Adventure,Fantasy
# 9  Action,Adventure,Fantasy

# %% [markdown]
# # Exploratory Data Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %% [markdown]
# ![Release Date](images/ReleaseDate.jpg)

# %%
# Extract the month from the release date
sorted_worldwide_gross_movie_budgets_df['release_month'] = pd.DatetimeIndex(sorted_worldwide_gross_movie_budgets_df['release_date']).month

# Group the data by release month and calculate the average worldwide gross
grouped = sorted_worldwide_gross_movie_budgets_df.groupby('release_month')['worldwide_gross'].mean()

# Define a list of colors for each bin
colors = ['blue', 'blue', 'blue', 'blue', 'red', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue']


# Create a histogram of the average worldwide gross by release month
plt.bar(grouped.index, grouped, color=colors)
plt.xlabel('Release Month')
plt.ylabel('Average Worldwide Gross(USD in Billions)')
plt.title('Average Worldwide Gross by Release Month')
# Set the tick locations and labels for the x-axis
plt.xticks(range(1, 13), range(1, 13))

plt.savefig('images/ReleaseDate.jpg')
plt.show()

# %%
genre_popularity_df = genre_popularity_df.explode('genre_ids').groupby('genre_ids')['popularity'].mean().reset_index()

# sort the genres by popularity in descending order
genre_popularity_df = genre_popularity_df.sort_values(by='popularity', ascending=False)

# select the top three genres by popularity
top_three_genres = genre_popularity_df['genre_ids'].head(3).tolist()

# print the top three genres
print(top_three_genres)
# Out:
# [12, 28, 14]

# %%
plt.figure(figsize = (20, 15))
plt.ticklabel_format(style='plain')
sns.regplot(
    data = sorted_worldwide_gross_movie_budgets_df, 
    x = "production_budget", 
    y = "worldwide_gross",
    scatter_kws = {"alpha": 0.1},
    line_kws = {"color": "red"}
)
plt.savefig("budget_wgross.jpg")

plt.xlabel('Production Budget (in millions)')
plt.gca().xaxis.set_major_formatter(ticker.FuncFormatter
        (lambda x, pos: f'{x/1000000:.0f}M'))

# Set the y-axis label and format the tick labels in millions
plt.ylabel('Worldwide Gross Revenue (in millions)')
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter
        (lambda x, pos: f'{x/1000000:.0f}M'))
plt.title('Correlation between Worldwide Gross and Production Budget', fontsize=20)


plt.savefig("budget_wgross.jpg")

# %%
# Graphing descriptive statistics for the data frame (histogram)
ax = sorted_popularity_tmdb_movies_df["popularity"].plot.hist(bins=30, alpha=0.5)
ax.set_xlabel("Popularity")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Graphing descriptive statistics for the data frame (histogram) Left skewed
ax = sorted_popularity_tmdb_movies_df["popularity"].plot.hist(bins=30, alpha=0.5)
ax.set_xlabel("Popularity")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Graphing descriptive statistics for the data frame (histogram) Left skewed
sorted_worldwide_gross_movie_budgets_df["worldwide_gross"].plot.hist(bins=30, alpha=0.5)
ax.set_xlabel("worldwide_gross")
ax.set_ylabel("Frequency")
# Out:
# Text(17.200000000000003, 0.5, 'Frequency')

# %%
# Graphing descriptive statistics for the data frame (histogram) Left skewed
sorted_movie_gross_domestic_df["domestic_gross"].plot.hist(bins=30, alpha=0.5)
ax.set_xlabel("domestic_gross")
ax.set_ylabel("Frequency")
# Out:
# Text(17.200000000000003, 0.5, 'Frequency')

# %% [markdown]
# We can see that the relationship between popularity and vote average is fairly normally distributed, as well as vote count and vote average.

# %%
sns.pairplot(sorted_popularity_tmdb_movies_df)

# %% [markdown]
# In general we can see below that there is a positive correlation between production budget and domestic and worldwide gross of a movie.

# %%
sns.pairplot(sorted_worldwide_gross_movie_budgets_df)

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
others_popularity = genre_popularity_df[~genre_popularity_df['genre_ids'].isin([12, 28])]['popularity'].mean()
others = pd.DataFrame({'genre_ids': ['Others'], 'popularity': [others_popularity]})

top_movies = genre_popularity_df[genre_popularity_df['genre_ids'].isin([12, 28])]
top_movies['genre_ids'] = top_movies['genre_ids'].replace({12: 'Adventure', 28: 'Action'})
top_movies = pd.concat([top_movies, others])

plt.figure(figsize=(12, 6))
sns.barplot(data=top_movies, x='genre_ids', y='popularity')
plt.xlabel('Genre')
plt.ylabel('Average Popularity')
plt.title('Average Popularity by Genre')
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# Through my analysis I found that the most popular movies in the box office over the past 10 years have been in the genre's of "Action" and "Adventure".
#
# In general there is a positive correlation between production budget and worldwide/domestic gross.
#
# On average the highest grossing movies have been released in the month of May.

# %% [markdown]
# ## Recommendations

# %% [markdown]
# Based on my findings I would recommend that Microsoft should create movies that are within the "Action" and "Adventure" genres as they have the highest popularity rating.
#
# I would recommend that Microsoft be prepared to investment more money into the production budget. Higher production budgets are more likely to lead to a higher grossing film.
#
# Releasing a movie in one of these 3 months: May,June,July. Which have shown to produce the highest grossing films on average.

# %% [markdown]
# ## Limitations

# %% [markdown]
# One limitation that I found while investigating the data sets was that there were too many missing values in certain data sets which effected my ability to use it. The biggest limitation was the lack of information on net profit for production companies. Having this information would help in determining a movie's a success. Looking into how much money went into advertising for example could be an element that would effect total profit. Having numbers on production budget and worldwide gross are very valuable but it still does not tell the whole story.

# %% [markdown]
# ## Next Steps

# %% [markdown]
# Exploring more data sets is always helpful. The more information we have at our fingertips will only strenghten knowledge on a particular subject and lead to the best course of action. I would look into data sets focusing more on production companies to try and gather more information on what goes into making a successful film. Looking at data sets that have information on how much money went into advertising and also how long the movie was actively advertised for would be crucial to look at to ensure the best steps are being taken to produce a successful movie. Also looking at merchandising sales for a movie would be another helpful factor in determining success.
